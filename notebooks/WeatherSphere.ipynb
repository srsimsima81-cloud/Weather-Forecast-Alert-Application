# %% [markdown]
# # 🍃 WeatherSphere Notebook 🌀
# ### Live Weather + Forecast Analysis System

# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")  # goes one level up from notebooks
sys.path.insert(0, PROJECT_ROOT)

print("Project root added:", PROJECT_ROOT)

from src.weather_api import fetch_weather
from src.alerts import generate_alerts
from src.forecast import parse_forecast
from src.weather_api import fetch_weather, fetch_forecast
from src.forecast import parse_forecast
# Out:
# Project root added: c:\Users\lenovo\OneDrive\Documents\Weather-Forecast-Alert-Application

# %%
city = "London"
data = fetch_weather(city)

data
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 20.21,
#   'feels_like': 19.36,
#   'temp_min': 19.32,
#   'temp_max': 21.06,
#   'pressure': 1016,
#   'humidity': 41,
#   'sea_level': 1016,
#   'grnd_level': 1012},
#  'visibility': 10000,
#  'wind': {'speed': 6.69, 'deg': 100},
#  'clouds': {'all': 96},
#  'dt': 1778341230,
#  'sys': {'type': 2,
#   'id': 2075535,
#   'country': 'GB',
#   'sunrise': 1778300303,
#   'sunset': 1778355333},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
forecast = fetch_forecast("London")
df = parse_forecast(forecast)

df.head()
# Out:
#               datetime   temp  humidity        condition
# 0  2026-05-09 18:00:00  19.72        43  overcast clouds
# 1  2026-05-09 21:00:00  15.55        55  overcast clouds
# 2  2026-05-10 00:00:00  10.13        58  overcast clouds
# 3  2026-05-10 03:00:00   7.95        69  overcast clouds
# 4  2026-05-10 06:00:00   9.45        75  overcast clouds

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))

plt.plot(df["datetime"], df["temp"], label="Temperature")
plt.plot(df["datetime"], df["humidity"], label="Humidity")

plt.xticks(rotation=45)
plt.legend()

plt.title("Weather Forecast Trend")

plt.tight_layout()
plt.show()
